# %% [markdown]
# ### Importing Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto_train_ds = pd.read_csv("Train.csv", sep=",")
auto_test_ds = pd.read_csv("Test.csv", sep=",")
auto_ds = pd.concat([auto_train_ds, auto_test_ds])

auto_ds
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# 1                 NaN        Average          3.0  Cat_4            A
# 2                 1.0            Low          1.0  Cat_6            B
# 3                 0.0           High          2.0  Cat_6            B
# 4                 NaN           High          6.0  Cat_6            A
# ...               ...            ...          ...    ...          ...
# 2622              9.0            Low          4.0  Cat_6            B
# 2623              1.0            Low          1.0  Cat_6            A
# 2624              NaN            Low          2.0  Cat_6            C
# 2625              1.0           High          5.0  Cat_4            C
# 2626              9.0            Low          3.0  Cat_7            A
#
# [10695 rows x 11 columns]

# %% [markdown]
# ### Data Preliminary Exploration

# %%
#Checking the existence of zeros in rows
(auto_ds==0).sum(axis=0)
# Out:
# ID                    0
# Gender                0
# Ever_Married          0
# Age                   0
# Graduated             0
# Profession            0
# Work_Experience    3087
# Spending_Score        0
# Family_Size           0
# Var_1                 0
# Segmentation          0
# dtype: int64

# %%
#Checking the existence of duplicated rows
auto_ds.duplicated().sum()
# Out:
# 38

# %%
#Checking data balancing (for classification)
auto_balancing = pd.DataFrame()
auto_balancing["Count"] = auto_ds["Segmentation"].value_counts()
auto_balancing["Count%"] = auto_ds["Segmentation"].value_counts()/auto_ds.shape[0]*100

auto_balancing
# Out:
#    Count  Count%
# D   3027   28.30
# A   2818   26.35
# C   2442   22.83
# B   2408   22.52

# %%
#Checking basic statistical data by feature
auto_ds.describe(include="all")
# Out:
#                ID Gender Ever_Married       Age Graduated Profession  \
# count   10,695.00  10695        10505 10,695.00     10593      10533
# unique        NaN      2            2       NaN         2          9
# top           NaN   Male          Yes       NaN       Yes     Artist
# freq          NaN   5841         6163       NaN      6570       3318
# mean   463,468.09    NaN          NaN     43.51       NaN        NaN
# std      2,600.97    NaN          NaN     16.77       NaN        NaN
# min    458,982.00    NaN          NaN     18.00       NaN        NaN
# 25%    461,220.50    NaN          NaN     30.00       NaN        NaN
# 50%    463,451.00    NaN          NaN     41.00       NaN        NaN
# 75%    465,733.50    NaN          NaN     53.00       NaN        NaN
# max    467,974.00    NaN          NaN     89.00       NaN        NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count          9,597.00          10695    10,247.00  10587        10695
# unique              NaN              3          NaN      7            4
# top                 NaN            Low          NaN  Cat_6            D
# freq                NaN           6494          NaN   6910         3027
# mean               2.62            NaN         2.84    NaN          NaN
# std                3.39            NaN         1.54    NaN          NaN
# min                0.00            NaN         1.00    NaN          NaN
# 25%                0.00            NaN         2.00    NaN          NaN
# 50%                1.00            NaN         3.00    NaN          NaN
# 75%                4.00            NaN         4.00    NaN          NaN
# max               14.00            NaN         9.00    NaN          NaN

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# 1. Remove duplicated rows (38 in total)
#
# 2. Treat missing values:
#     *   3.1 Ever_Married: consider missing values as No
#     *   3.2 Graduated: consider missing values as No
#     *   3.3 Profession: delete (it´s not representative the amount of blanks)
#     *   3.4 Family_Size: mean
#     *   3.5 Var_1: delete (it´s not representative the amount of blanks)
#     *   3.6 Work_Experience: estimate based on Age
#
#
# 3. Remove column ID as it´s not important to the model
#
# 4. Convert categorical variables (Gender, Ever_Married, Graduated, Profession, Spending_Score, Var_1, Segmentation) to dummies

# %%
#1
auto_ds.drop_duplicates(inplace=True)

# %%
#2
auto_ds["Ever_Married"].fillna("No", inplace=True)
auto_ds["Graduated"].fillna("No", inplace=True)
auto_ds.dropna(subset=["Profession"], inplace=True)
auto_ds["Family_Size"].fillna(auto_ds["Family_Size"].mean(), inplace=True)
auto_ds.dropna(subset=["Var_1"], inplace=True)
auto_ds["Work_Experience"].replace(0, np.nan, inplace=True)
auto_ds["Work_Experience"].fillna(auto_ds["Work_Experience"].sum() / auto_ds["Age"].sum() * auto_ds["Age"], inplace=True)

# %%
#3
auto_ds.drop(["ID"], axis=1, inplace=True)

# %%
#4
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Gender"], prefix="Gender")], axis=1)
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Ever_Married"], prefix="Ever_Married")], axis=1)
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Graduated"], prefix="Graduated")], axis=1)
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Profession"], prefix="Profession")], axis=1)
auto_ds["Spending_Score_Level"] = auto_ds["Spending_Score"].apply(lambda x: ["Low", "Average", "High"].index(x))+1 #Label encoding
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Var_1"], prefix="Var_1")], axis=1)
#target variable for the ML model (label encoding)
auto_ds["Segmentation_Level"] = auto_ds["Segmentation"].apply(lambda x: ["A", "B", "C", "D"].index(x))+1 #Label encoding
#target variable for the DL model (one-hot encoding)
auto_ds = pd.concat([auto_ds, pd.get_dummies(auto_ds["Segmentation"], prefix="Segmentation")], axis=1)
Segmentation_encoding_dl = np.asarray(auto_ds[["Segmentation_A", "Segmentation_B", "Segmentation_C", "Segmentation_D"]]) #creating for the DL model the response variable through the concatenation of the created dummy columns, forming an array

# %% [markdown]
# ### Features Selection

# %%
auto_ds.drop(["Segmentation", "Gender", "Ever_Married", "Graduated", "Profession", "Spending_Score", "Var_1"], axis=1, inplace=True)

# %%
#Plotting a Feature Importance

from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot
#Defining Xs and y
X = auto_ds.drop(["Segmentation_Level"], axis=1)
y = auto_ds["Segmentation_Level"]
#Defining the model
model = RandomForestClassifier().fit(X, y)
#Getting importance
importance = model.feature_importances_
#Summarizing feature importance
for i,v in enumerate(importance):
    print("Feature:{0:}, Score:{1:,.4f}".format(X.columns[i], v))
#Plotting feature importance
pd.Series(model.feature_importances_[::-1], index=X.columns[::-1]).plot(kind="barh", figsize=(25,25))
# Out:
# Feature:Age, Score:0.0232
# Feature:Work_Experience, Score:0.0033
# Feature:Family_Size, Score:0.0043
# Feature:Gender_Female, Score:0.0006
# Feature:Gender_Male, Score:0.0005
# Feature:Ever_Married_No, Score:0.0072
# Feature:Ever_Married_Yes, Score:0.0060
# Feature:Graduated_No, Score:0.0046
# Feature:Graduated_Yes, Score:0.0047
# Feature:Profession_Artist, Score:0.0061
# Feature:Profession_Doctor, Score:0.0003
# Feature:Profession_Engineer, Score:0.0007
# Feature:Profession_Entertainment, Score:0.0009
# Feature:Profession_Executive, Score:0.0003
# Feature:Profession_Healthcare, Score:0.0071
# Feature:Profession_Homemaker, Score:0.0003
# Feature:Profession_Lawyer, Score:0.0004
# Feature:Profession_Marketing, Score:0.0008
# Feature:Spending_Score_Level, Score:0.0098
# Feature:Var_1_Cat_1, Score:0.0002
# Feature:Var_1_Cat_2, Score:0.0003
# Feature:Var_1_Cat_3, Score:0.0004
# Feature:Var_1_Cat_4, Score:0.0009
# Feature:Var_1_Cat_5, Score:0.0001
# Feature:Var_1_Cat_6, Score:0.0007
# Feature:Var_1_Cat_7, Score:0.0002
# Feature:Segmentation_A, Score:0.2494
# Feature:Segmentation_B, Score:0.2055
# Feature:Segmentation_C, Score:0.2248
# Feature:Segmentation_D, Score:0.2364
# <AxesSubplot:>

# %% [markdown]
# ### Data Modelling

# %%
#Defining Xs and y

X = auto_ds[["Age", "Family_Size", "Profession_Healthcare", "Work_Experience", "Profession_Artist", "Ever_Married_Yes",
             "Graduated_No", "Spending_Score_Level"]]
y = auto_ds["Segmentation_Level"]
y_dl = Segmentation_encoding_dl #for the DL model

#Scaling all features

from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X_scaled = sc_X.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled)

#Setting train/test split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=0)
X_train_dl, X_test_dl, y_train_dl, y_test_dl = train_test_split(X_scaled, y_dl, random_state=0) #for the DL model

# %% [markdown]
# ### Machine learning

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# Định nghĩa mô hình
model = linear_model.LogisticRegression(max_iter=1000)

# Huấn luyện mô hình trên tập huấn luyện
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Predict on test set
y_pred = model.predict(X_test)

# Calculate evaluation metrics
acc = accuracy_score(y_test, y_pred)

print('Accuracy:', acc)
# Out:
# Accuracy: 0.4565050038491147

# %% [markdown]
# #### K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 49
knn = KNeighborsClassifier(n_neighbors=k)
score = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy').mean()

print(f"The optimal number of neighbors is {k}")
print(score)
# Out:
# The optimal number of neighbors is 49
# 0.45944570619795266

# %% [markdown]
# #### Support Vector Machines (SVM)

# %%
from sklearn import svm

linear_svm = svm.SVC(kernel='linear')
linear_svm_score = cross_val_score(linear_svm, X_train, y_train, cv=10, scoring='accuracy').mean()
print(linear_svm_score)
# Out:
# 0.43339620157335174

# %% [markdown]
# #### Linear and RBF Kernels

# %%
rbf = svm.SVC(kernel='rbf')
rbf_score = cross_val_score(rbf, X_train, y_train, cv=10, scoring='accuracy').mean()
print(rbf_score)
# Out:
# 0.4639366709456568

# %% [markdown]
# ### Deep Learning

# %%
#Creating a Deep Learning model and checking its Metrics

from keras import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
pd.options.mode.chained_assignment = None

#Creating a model
model_dl = Sequential()

#Input and First Hidden Layer
model_dl.add(Dense(units=256, activation="relu", input_dim=X_train.shape[1]))
model_dl.add(Dropout(0.25))
model_dl.add(Dense(64, activation='relu'))
model_dl.add(Dropout(0.25))
model_dl.add(Dense(128, activation='relu'))
#Output Layer
model_dl.add(Dense(units=4, activation="softmax"))

#Compiling the neural network
model_dl.compile(optimizer="Adam", loss="CategoricalCrossentropy", metrics=["CategoricalAccuracy"])

#Fitting to the model
model_dl.fit(X_train_dl, y_train_dl, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 244/244 [==============================] - 2s 3ms/step - loss: 1.2528 - categorical_accuracy: 0.4268
# Epoch 2/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.2169 - categorical_accuracy: 0.4520
# Epoch 3/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.2083 - categorical_accuracy: 0.4512
# Epoch 4/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.2028 - categorical_accuracy: 0.4583
# Epoch 5/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1991 - categorical_accuracy: 0.4605
# Epoch 6/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1925 - categorical_accuracy: 0.4618
# Epoch 7/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1943 - categorical_accuracy: 0.4643
# Epoch 8/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1872 - categorical_accuracy: 0.4750
# Epoch 9/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1841 - categorical_accuracy: 0.4750
# Epoch 10/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1838 - categorical_accuracy: 0.4678
# Epoch 11/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1767 - categorical_accuracy: 0.4763
# Epoch 12/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1819 - categorical_accuracy: 0.4707
# Epoch 13/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1796 - categorical_accuracy: 0.4720
# Epoch 14/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1795 - categorical_accuracy: 0.4693
# Epoch 15/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1757 - categorical_accuracy: 0.4751
# Epoch 16/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1753 - categorical_accuracy: 0.4733
# Epoch 17/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1697 - categorical_accuracy: 0.4774
# Epoch 18/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1742 - categorical_accuracy: 0.4763
# Epoch 19/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1741 - categorical_accuracy: 0.4802
# Epoch 20/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1701 - categorical_accuracy: 0.4799
# Epoch 21/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1718 - categorical_accuracy: 0.4792
# Epoch 22/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1707 - categorical_accuracy: 0.4795
# Epoch 23/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1694 - categorical_accuracy: 0.4820
# Epoch 24/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1662 - categorical_accuracy: 0.4819
# Epoch 25/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1666 - categorical_accuracy: 0.4824
# Epoch 26/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1707 - categorical_accuracy: 0.4807
# Epoch 27/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1657 - categorical_accuracy: 0.4855
# Epoch 28/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1669 - categorical_accuracy: 0.4810
# Epoch 29/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1661 - categorical_accuracy: 0.4855
# Epoch 30/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1635 - categorical_accuracy: 0.4828
# Epoch 31/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1633 - categorical_accuracy: 0.4863
# Epoch 32/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1612 - categorical_accuracy: 0.4874
# Epoch 33/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1641 - categorical_accuracy: 0.4834
# Epoch 34/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1636 - categorical_accuracy: 0.4829
# Epoch 35/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1619 - categorical_accuracy: 0.4890
# Epoch 36/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1594 - categorical_accuracy: 0.4868
# Epoch 37/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1589 - categorical_accuracy: 0.4854
# Epoch 38/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1612 - categorical_accuracy: 0.4896
# Epoch 39/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1608 - categorical_accuracy: 0.4854
# Epoch 40/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1626 - categorical_accuracy: 0.4877
# Epoch 41/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1579 - categorical_accuracy: 0.4873
# Epoch 42/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1542 - categorical_accuracy: 0.4888
# Epoch 43/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1571 - categorical_accuracy: 0.4887
# Epoch 44/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1576 - categorical_accuracy: 0.4816
# Epoch 45/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1580 - categorical_accuracy: 0.4847
# Epoch 46/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1580 - categorical_accuracy: 0.4876
# Epoch 47/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1563 - categorical_accuracy: 0.4872
# Epoch 48/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1539 - categorical_accuracy: 0.4805
# Epoch 49/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1542 - categorical_accuracy: 0.4836
# Epoch 50/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1532 - categorical_accuracy: 0.4879
# Epoch 51/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1493 - categorical_accuracy: 0.4904
# Epoch 52/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1505 - categorical_accuracy: 0.4884
# Epoch 53/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1517 - categorical_accuracy: 0.4909
# Epoch 54/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1506 - categorical_accuracy: 0.4873
# Epoch 55/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1496 - categorical_accuracy: 0.4909
# Epoch 56/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1503 - categorical_accuracy: 0.4922
# Epoch 57/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1495 - categorical_accuracy: 0.4895
# Epoch 58/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1508 - categorical_accuracy: 0.4901
# Epoch 59/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1474 - categorical_accuracy: 0.4879
# Epoch 60/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1495 - categorical_accuracy: 0.4918
# Epoch 61/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1505 - categorical_accuracy: 0.4891
# Epoch 62/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1482 - categorical_accuracy: 0.4878
# Epoch 63/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1471 - categorical_accuracy: 0.4937
# Epoch 64/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1456 - categorical_accuracy: 0.4886
# Epoch 65/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1430 - categorical_accuracy: 0.4964
# Epoch 66/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1462 - categorical_accuracy: 0.4914
# Epoch 67/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1419 - categorical_accuracy: 0.4906
# Epoch 68/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1443 - categorical_accuracy: 0.4931
# Epoch 69/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1413 - categorical_accuracy: 0.4937
# Epoch 70/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1472 - categorical_accuracy: 0.4955
# Epoch 71/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1463 - categorical_accuracy: 0.4886
# Epoch 72/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1441 - categorical_accuracy: 0.4918
# Epoch 73/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1386 - categorical_accuracy: 0.4922
# Epoch 74/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1441 - categorical_accuracy: 0.4914
# Epoch 75/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1415 - categorical_accuracy: 0.4928
# Epoch 76/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1396 - categorical_accuracy: 0.4924
# Epoch 77/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1371 - categorical_accuracy: 0.5027
# Epoch 78/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1406 - categorical_accuracy: 0.4928
# Epoch 79/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1398 - categorical_accuracy: 0.4964
# Epoch 80/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1414 - categorical_accuracy: 0.4940
# Epoch 81/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1401 - categorical_accuracy: 0.4950
# Epoch 82/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1387 - categorical_accuracy: 0.4955
# Epoch 83/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1357 - categorical_accuracy: 0.4988
# Epoch 84/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1413 - categorical_accuracy: 0.4942
# Epoch 85/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1405 - categorical_accuracy: 0.4938
# Epoch 86/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1351 - categorical_accuracy: 0.4988
# Epoch 87/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1375 - categorical_accuracy: 0.4987
# Epoch 88/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1355 - categorical_accuracy: 0.5022
# Epoch 89/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1372 - categorical_accuracy: 0.4947
# Epoch 90/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1347 - categorical_accuracy: 0.4986
# Epoch 91/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1345 - categorical_accuracy: 0.4953
# Epoch 92/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1361 - categorical_accuracy: 0.4990
# Epoch 93/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1351 - categorical_accuracy: 0.4936
# Epoch 94/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1332 - categorical_accuracy: 0.4987
# Epoch 95/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1375 - categorical_accuracy: 0.4941
# Epoch 96/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1324 - categorical_accuracy: 0.5026
# Epoch 97/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1331 - categorical_accuracy: 0.4986
# Epoch 98/100
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1343 - categorical_accuracy: 0.4988
# Epoch 99/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1312 - categorical_accuracy: 0.4978
# Epoch 100/100
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1324 - categorical_accuracy: 0.4981

# %%
score = model_dl.evaluate(X_test_dl, y_test_dl, verbose=0)
print('Độ chính xác của mô hình là:', score[1])
# Out:
# Độ chính xác của mô hình là: 0.47305619716644287

# %%
#Fitting to the model
model_dl.fit(X_train_dl, y_train_dl, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1318 - categorical_accuracy: 0.4960
# Epoch 2/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1308 - categorical_accuracy: 0.4999
# Epoch 3/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1316 - categorical_accuracy: 0.4965
# Epoch 4/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1302 - categorical_accuracy: 0.5014
# Epoch 5/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1296 - categorical_accuracy: 0.5008
# Epoch 6/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1304 - categorical_accuracy: 0.5013
# Epoch 7/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1296 - categorical_accuracy: 0.4981
# Epoch 8/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1268 - categorical_accuracy: 0.5024
# Epoch 9/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1301 - categorical_accuracy: 0.5014
# Epoch 10/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1248 - categorical_accuracy: 0.5032
# Epoch 11/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1265 - categorical_accuracy: 0.5039
# Epoch 12/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1289 - categorical_accuracy: 0.5022
# Epoch 13/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1258 - categorical_accuracy: 0.5008
# Epoch 14/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1276 - categorical_accuracy: 0.5051
# Epoch 15/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1310 - categorical_accuracy: 0.5014
# Epoch 16/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1273 - categorical_accuracy: 0.5058
# Epoch 17/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1246 - categorical_accuracy: 0.5037
# Epoch 18/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1231 - categorical_accuracy: 0.5050
# Epoch 19/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1216 - categorical_accuracy: 0.5018
# Epoch 20/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.1265 - categorical_accuracy: 0.4983
# Epoch 21/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1239 - categorical_accuracy: 0.5096
# Epoch 22/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1250 - categorical_accuracy: 0.5012
# Epoch 23/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1222 - categorical_accuracy: 0.5041
# Epoch 24/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1240 - categorical_accuracy: 0.5042
# Epoch 25/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1247 - categorical_accuracy: 0.4995
# Epoch 26/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1206 - categorical_accuracy: 0.5033
# Epoch 27/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1190 - categorical_accuracy: 0.5104
# Epoch 28/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1222 - categorical_accuracy: 0.5036
# Epoch 29/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1195 - categorical_accuracy: 0.5060
# Epoch 30/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1180 - categorical_accuracy: 0.5109
# Epoch 31/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1251 - categorical_accuracy: 0.5078
# Epoch 32/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1204 - categorical_accuracy: 0.5056
# Epoch 33/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1193 - categorical_accuracy: 0.5077
# Epoch 34/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1195 - categorical_accuracy: 0.5123
# Epoch 35/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1216 - categorical_accuracy: 0.5049
# Epoch 36/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1147 - categorical_accuracy: 0.5076
# Epoch 37/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1185 - categorical_accuracy: 0.5051
# Epoch 38/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1220 - categorical_accuracy: 0.5076
# Epoch 39/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1176 - categorical_accuracy: 0.5022
# Epoch 40/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1176 - categorical_accuracy: 0.5077
# Epoch 41/200
# 244/244 [==============================] - 1s 6ms/step - loss: 1.1135 - categorical_accuracy: 0.5087
# Epoch 42/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1098 - categorical_accuracy: 0.5104
# Epoch 43/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1176 - categorical_accuracy: 0.5091
# Epoch 44/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1197 - categorical_accuracy: 0.5116
# Epoch 45/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1140 - categorical_accuracy: 0.5078
# Epoch 46/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1163 - categorical_accuracy: 0.5094
# Epoch 47/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.1167 - categorical_accuracy: 0.5078
# Epoch 48/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1166 - categorical_accuracy: 0.5094
# Epoch 49/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.1121 - categorical_accuracy: 0.5090
# Epoch 50/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1101 - categorical_accuracy: 0.5119
# Epoch 51/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1130 - categorical_accuracy: 0.5144
# Epoch 52/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.1137 - categorical_accuracy: 0.5096
# Epoch 53/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1126 - categorical_accuracy: 0.5124
# Epoch 54/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1127 - categorical_accuracy: 0.5114
# Epoch 55/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1191 - categorical_accuracy: 0.5078
# Epoch 56/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1088 - categorical_accuracy: 0.5118
# Epoch 57/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1157 - categorical_accuracy: 0.5019
# Epoch 58/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1134 - categorical_accuracy: 0.5060
# Epoch 59/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1113 - categorical_accuracy: 0.5054
# Epoch 60/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1117 - categorical_accuracy: 0.5137
# Epoch 61/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1106 - categorical_accuracy: 0.5108
# Epoch 62/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.1071 - categorical_accuracy: 0.5108
# Epoch 63/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1085 - categorical_accuracy: 0.5094
# Epoch 64/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1129 - categorical_accuracy: 0.5058
# Epoch 65/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1107 - categorical_accuracy: 0.5099
# Epoch 66/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1099 - categorical_accuracy: 0.5119
# Epoch 67/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1082 - categorical_accuracy: 0.5119
# Epoch 68/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1071 - categorical_accuracy: 0.5100
# Epoch 69/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1129 - categorical_accuracy: 0.5117
# Epoch 70/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1095 - categorical_accuracy: 0.5113
# Epoch 71/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1055 - categorical_accuracy: 0.5118
# Epoch 72/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1062 - categorical_accuracy: 0.5158
# Epoch 73/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1076 - categorical_accuracy: 0.5176
# Epoch 74/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1067 - categorical_accuracy: 0.5178
# Epoch 75/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1114 - categorical_accuracy: 0.5063
# Epoch 76/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1050 - categorical_accuracy: 0.5083
# Epoch 77/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1068 - categorical_accuracy: 0.5110
# Epoch 78/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1055 - categorical_accuracy: 0.5185
# Epoch 79/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1053 - categorical_accuracy: 0.5131
# Epoch 80/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1027 - categorical_accuracy: 0.5118
# Epoch 81/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1042 - categorical_accuracy: 0.5114
# Epoch 82/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1023 - categorical_accuracy: 0.5141
# Epoch 83/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1028 - categorical_accuracy: 0.5153
# Epoch 84/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1057 - categorical_accuracy: 0.5157
# Epoch 85/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1015 - categorical_accuracy: 0.5132
# Epoch 86/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1041 - categorical_accuracy: 0.5167
# Epoch 87/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0983 - categorical_accuracy: 0.5157
# Epoch 88/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1036 - categorical_accuracy: 0.5145
# Epoch 89/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1016 - categorical_accuracy: 0.5151
# Epoch 90/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1055 - categorical_accuracy: 0.5158
# Epoch 91/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0981 - categorical_accuracy: 0.5181
# Epoch 92/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0993 - categorical_accuracy: 0.5126
# Epoch 93/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1022 - categorical_accuracy: 0.5154
# Epoch 94/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1006 - categorical_accuracy: 0.5184
# Epoch 95/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1025 - categorical_accuracy: 0.5189
# Epoch 96/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0986 - categorical_accuracy: 0.5227
# Epoch 97/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1002 - categorical_accuracy: 0.5131
# Epoch 98/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1018 - categorical_accuracy: 0.5169
# Epoch 99/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.1001 - categorical_accuracy: 0.5154
# Epoch 100/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0981 - categorical_accuracy: 0.5146
# Epoch 101/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0995 - categorical_accuracy: 0.5208
# Epoch 102/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0954 - categorical_accuracy: 0.5186
# Epoch 103/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0979 - categorical_accuracy: 0.5173
# Epoch 104/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0981 - categorical_accuracy: 0.5142
# Epoch 105/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0955 - categorical_accuracy: 0.5176
# Epoch 106/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.1011 - categorical_accuracy: 0.5198
# Epoch 107/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0984 - categorical_accuracy: 0.5150
# Epoch 108/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0952 - categorical_accuracy: 0.5162
# Epoch 109/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0996 - categorical_accuracy: 0.5139
# Epoch 110/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0963 - categorical_accuracy: 0.5160
# Epoch 111/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0971 - categorical_accuracy: 0.5184
# Epoch 112/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0965 - categorical_accuracy: 0.5234
# Epoch 113/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0924 - categorical_accuracy: 0.5172
# Epoch 114/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0962 - categorical_accuracy: 0.5210
# Epoch 115/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0944 - categorical_accuracy: 0.5116
# Epoch 116/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0923 - categorical_accuracy: 0.5186
# Epoch 117/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0928 - categorical_accuracy: 0.5213
# Epoch 118/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0932 - categorical_accuracy: 0.5200
# Epoch 119/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0978 - categorical_accuracy: 0.5182
# Epoch 120/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0900 - categorical_accuracy: 0.5222
# Epoch 121/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0996 - categorical_accuracy: 0.5180
# Epoch 122/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0980 - categorical_accuracy: 0.5154
# Epoch 123/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0944 - categorical_accuracy: 0.5142
# Epoch 124/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0917 - categorical_accuracy: 0.5172
# Epoch 125/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0943 - categorical_accuracy: 0.5222
# Epoch 126/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0930 - categorical_accuracy: 0.5205
# Epoch 127/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0942 - categorical_accuracy: 0.5169
# Epoch 128/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0912 - categorical_accuracy: 0.5205
# Epoch 129/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0921 - categorical_accuracy: 0.5207
# Epoch 130/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0935 - categorical_accuracy: 0.5219
# Epoch 131/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0922 - categorical_accuracy: 0.5195
# Epoch 132/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0974 - categorical_accuracy: 0.5178
# Epoch 133/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0902 - categorical_accuracy: 0.5207
# Epoch 134/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0939 - categorical_accuracy: 0.5196
# Epoch 135/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0886 - categorical_accuracy: 0.5213
# Epoch 136/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0895 - categorical_accuracy: 0.5232
# Epoch 137/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0934 - categorical_accuracy: 0.5171
# Epoch 138/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0915 - categorical_accuracy: 0.5216
# Epoch 139/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0837 - categorical_accuracy: 0.5264
# Epoch 140/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0903 - categorical_accuracy: 0.5173
# Epoch 141/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0878 - categorical_accuracy: 0.5225
# Epoch 142/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0849 - categorical_accuracy: 0.5205
# Epoch 143/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0895 - categorical_accuracy: 0.5200
# Epoch 144/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0840 - categorical_accuracy: 0.5235
# Epoch 145/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0937 - categorical_accuracy: 0.5185
# Epoch 146/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0917 - categorical_accuracy: 0.5178
# Epoch 147/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0920 - categorical_accuracy: 0.5169
# Epoch 148/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0909 - categorical_accuracy: 0.5175
# Epoch 149/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0839 - categorical_accuracy: 0.5218
# Epoch 150/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0880 - categorical_accuracy: 0.5249
# Epoch 151/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0864 - categorical_accuracy: 0.5162
# Epoch 152/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0922 - categorical_accuracy: 0.5177
# Epoch 153/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0855 - categorical_accuracy: 0.5191
# Epoch 154/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0956 - categorical_accuracy: 0.5216
# Epoch 155/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0845 - categorical_accuracy: 0.5208
# Epoch 156/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0869 - categorical_accuracy: 0.5187
# Epoch 157/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0899 - categorical_accuracy: 0.5201
# Epoch 158/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0820 - categorical_accuracy: 0.5243
# Epoch 159/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0821 - categorical_accuracy: 0.5246
# Epoch 160/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0892 - categorical_accuracy: 0.5187
# Epoch 161/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0896 - categorical_accuracy: 0.5226
# Epoch 162/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0865 - categorical_accuracy: 0.5240
# Epoch 163/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0895 - categorical_accuracy: 0.5200
# Epoch 164/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0891 - categorical_accuracy: 0.5237
# Epoch 165/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0851 - categorical_accuracy: 0.5223
# Epoch 166/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0814 - categorical_accuracy: 0.5295
# Epoch 167/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0882 - categorical_accuracy: 0.5241
# Epoch 168/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0848 - categorical_accuracy: 0.5209
# Epoch 169/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0836 - categorical_accuracy: 0.5227
# Epoch 170/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0839 - categorical_accuracy: 0.5181
# Epoch 171/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0832 - categorical_accuracy: 0.5241
# Epoch 172/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0848 - categorical_accuracy: 0.5254
# Epoch 173/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0860 - categorical_accuracy: 0.5228
# Epoch 174/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0839 - categorical_accuracy: 0.5241
# Epoch 175/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0811 - categorical_accuracy: 0.5222
# Epoch 176/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0835 - categorical_accuracy: 0.5186
# Epoch 177/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0780 - categorical_accuracy: 0.5316
# Epoch 178/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0815 - categorical_accuracy: 0.5257
# Epoch 179/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0860 - categorical_accuracy: 0.5226
# Epoch 180/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0784 - categorical_accuracy: 0.5273
# Epoch 181/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0806 - categorical_accuracy: 0.5249
# Epoch 182/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0814 - categorical_accuracy: 0.5302
# Epoch 183/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0820 - categorical_accuracy: 0.5262
# Epoch 184/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0834 - categorical_accuracy: 0.5258
# Epoch 185/200
# 244/244 [==============================] - 1s 4ms/step - loss: 1.0737 - categorical_accuracy: 0.5290
# Epoch 186/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0815 - categorical_accuracy: 0.5232
# Epoch 187/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0833 - categorical_accuracy: 0.5227
# Epoch 188/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0788 - categorical_accuracy: 0.5267
# Epoch 189/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0790 - categorical_accuracy: 0.5314
# Epoch 190/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0825 - categorical_accuracy: 0.5303
# Epoch 191/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0774 - categorical_accuracy: 0.5234
# Epoch 192/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0845 - categorical_accuracy: 0.5218
# Epoch 193/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0815 - categorical_accuracy: 0.5263
# Epoch 194/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0792 - categorical_accuracy: 0.5314
# Epoch 195/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0766 - categorical_accuracy: 0.5234
# Epoch 196/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0768 - categorical_accuracy: 0.5232
# Epoch 197/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0782 - categorical_accuracy: 0.5249
# Epoch 198/200
# 244/244 [==============================] - 1s 3ms/step - loss: 1.0780 - categorical_accuracy: 0.5293
# Epoch 199/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0775 - categorical_accuracy: 0.5250
# Epoch 200/200
# 244/244 [==============================] - 1s 2ms/step - loss: 1.0824 - categorical_accuracy: 0.5294

# %%
score = model_dl.evaluate(X_test_dl, y_test_dl, verbose=0)
print('Độ chính xác của mô hình là:', score[1])
# Out:
# Độ chính xác của mô hình là: 0.4668976068496704

# %%
print("Shape of the Dataset:", X_train_dl.shape)
# Out:
# Shape of the Dataset: (7792, 8)
